# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
n = 1000000
nbins = 100
data = np.random.random(n)
data
# Out:
# array([0.26996451, 0.82393654, 0.95597548, ..., 0.16808136, 0.41003855,
#        0.08748221])

# %%
plt.hist(data, bins = nbins, density = True)
plt.plot([0,1],[1,1])
plt.show()
